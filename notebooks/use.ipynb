# %%
# !pip install -q -r requirements.txt

# %%
# As a module
from handball_foul import analyze_handball

# %%
result = analyze_handball("input.mp4", output_path="output/annotated.mp4")
print(result["final_verdict"])  # e.g. "HANDBALL FOUL"
print(result["is_foul"])        # True/False
print(result["reason"])         # Human-readable explanation

# From command line
# python handball_foul.py input.mp4 output/annotated.mp4
